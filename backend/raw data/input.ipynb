# %%
import pandas as pd

# %%
df = pd.read_csv('./data.csv')
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
#                 date     views    likes  \
# 0      December 2021    404000    12000
# 1      February 2022    214000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    link
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5439 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %%
df_cleaned = df.dropna()

# %%
def row_to_json(row):
  return {
    'title': row['title'],
    'author': row['author'],
    'date': row['date'],
    'views': row['views'],
    'likes': row['likes'],
    'link': row['link']
  }

# %%
import requests
url = 'http://localhost:8080/input'

# %%
for index, row in df_cleaned.iterrows():
  json_data = row_to_json(row)
  response = requests.post(url, json=json_data)
  
  if response.ok:
    print(f'Data untuk "{row["title"]}" berhasil dikirim.')
  else:
    print(f'Gagal mengirim data untuk "{row["title"]}".')
# Out:
# Data untuk "Climate action needs new frontline leadership" berhasil dikirim.
# Data untuk "The dark history of the overthrow of Hawaii" berhasil dikirim.
# Data untuk "How play can spark new ideas for your business" berhasil dikirim.
# Data untuk "Why is China appointing judges to combat climate change?" berhasil dikirim.
# Data untuk "Cement's carbon problem — and 2 ways to fix it" berhasil dikirim.
# Data untuk "The tragedy of air pollution — and an urgent demand for clean air" berhasil dikirim.
# Data untuk "The myth of Narcissus and Echo" berhasil dikirim.
# Data untuk "You deserve the right to repair your stuff" berhasil dikirim.
# Data untuk "What nature can teach us about sustainable business" berhasil dikirim.
# Data untuk "The origins of blackface and Black stereotypes" berhasil dikirim.
# Data untuk "A sex therapist's secret to rediscovering your spark" berhasil dikirim.
# Data untuk "How do jetpacks work? And why don't we all have them?" berhasil dikirim.
# Data untuk "What regret can teach you about living a good life" berhasil dikirim.
# Data untuk "How to fix the "bugs" in the net-zero code" berhasil dikirim.
# Data untuk ""Big Yellow Taxi" / "Song for Sunshine"" berhasil dikirim.
# Data untuk "How film captures the space between hope and despair" berhasil dikirim.
# Data untuk "What is "normal" and what is "different"?" berhasil dikirim.
# Data untuk "The ocean's ingenious climate solutions" berhasil dikirim.
# Data untuk "How we're reducing the climate impact of electronics" berhasil dikirim.
# Data untuk "A vibrant dance performance of funk classics" berhasil dikirim.
# Data untuk ""Dive In"" berhasil dikirim.
# Data untuk "Got millet? How marketing could improve the lives of African farmers" berhasil dikirim.
# Data untuk "The myth of Gawain and the Green Knight" berhasil dikirim.
# Data untuk "How wind energy could power Earth ... 18 times over" berhasil dikirim.
# Data untuk "The incredible cancer-detecting potential of photoacoustic imaging" berhasil dikirim.
# Data untuk "How to fix two of the most broken systems in the US" berhasil dikirim.
# Data untuk "Can you outsmart the fallacy that divided a nation?" berhasil dikirim.
# Data untuk "Sex education should start with consent" berhasil dikirim.
# Data untuk "Smart solutions to decarbonize buildings" berhasil dikirim.
# Data untuk "How to provide cooling for everyone — without warming the planet" berhasil dikirim.
# Data untuk "The mind-bending art of deep time" berhasil dikirim.
# Data untuk "The myth of Anansi, the trickster spider" berhasil dikirim.
# Data untuk " A different understanding of American patriotism" berhasil dikirim.
# Data untuk "4 ways to redefine power at work to include women of color" berhasil dikirim.
# Data untuk "How to boost nature-based solutions to climate change" berhasil dikirim.
# Data untuk "Which animal has the best eyesight?" berhasil dikirim.
# Data untuk "The new reality of fashion is digital" berhasil dikirim.
# Data untuk "Are brain waves the secret to treating Alzheimer's?" berhasil dikirim.
# Data untuk "What if women built the world they want to see?" berhasil dikirim.
# Data untuk "How to fix broken supply chains" berhasil dikirim.
# Data untuk "Can you solve the birthday cake riddle?" berhasil dikirim.
# Data untuk "What you need to know about carbon removal" berhasil dikirim.
# Data untuk "How radical hospitality can change the lives of the formerly incarcerated" berhasil dikirim.
# Data untuk "The tragic myth of the Sun God's son" berhasil dikirim.
# Data untuk "The unexpected, underwater plant fighting climate change" berhasil dikirim.
# Data untuk "How to break down barriers and not accept limits" berhasil dikirim.
# Data untuk ""A Ride With Polly Jean" / "Ali Farka Touche"" berhasil dikirim.
# Data untuk "Why do cats have vertical pupils?" berhasil dikirim.
# Data untuk "Why great leaders take humor seriously" berhasil dikirim.
# Data untuk "One company at a time" berhasil dikirim.
# Data untuk "How comic strips create better health care" berhasil dikirim.
# Data untuk "Why is it so hard to escape poverty?" berhasil dikirim.
# Data untuk ""You and I" / "Attention"" berhasil dikirim.
# Data untuk "How to realistically decarbonize the oil and gas industry" berhasil dikirim.
# Data untuk "I'm tired of people telling me to "grind"" berhasil dikirim.
# Data untuk "How biochar removes CO2 from the air — and helps farmers thrive" berhasil dikirim.
# Data untuk "The creativity, innovation and ingenuity languishing in US prisons" berhasil dikirim.
# Data untuk "The architectural mastermind behind modern Singapore" berhasil dikirim.
# Data untuk "The myth of Loki's monstrous children" berhasil dikirim.
# Data untuk "What makes a job "good" — and the case for investing in people" berhasil dikirim.
# Data untuk "Language shouldn't be a barrier to climate action" berhasil dikirim.
# Data untuk "Human-centered justice" berhasil dikirim.
# Data untuk "Why is the Mona Lisa so famous?" berhasil dikirim.
# Data untuk "How moms shape the world" berhasil dikirim.
# Data untuk "Why a free and fair internet is more vital than ever" berhasil dikirim.
# Data untuk "It's time to write a new climate story" berhasil dikirim.
# Data untuk "Blood, concrete, and dynamite: Building the Hoover Dam" berhasil dikirim.
# Data untuk "4 ways the COVID-19 pandemic changed the way we sleep" berhasil dikirim.
# Data untuk "You can only save one— who do you choose?" berhasil dikirim.
# Data untuk "How to escape the cynicism trap" berhasil dikirim.
# Data untuk "Use your voice, vote and wallet for climate action" berhasil dikirim.
# Data untuk "A king cobra bite — and a scientific discovery" berhasil dikirim.
# Data untuk "How we could better predict and stop floods" berhasil dikirim.
# Data untuk "Dreams and details for a decarbonized future" berhasil dikirim.
# Data untuk "The dark history of Mount Rushmore" berhasil dikirim.
# Data untuk "Siri, Alexa, Google ... what comes next?" berhasil dikirim.
# Data untuk "A new way to help young people with their mental health" berhasil dikirim.
# Data untuk "How to deal with your insomnia — and finally get to sleep" berhasil dikirim.
# Data untuk "Would you raise the bird that murdered your children?" berhasil dikirim.
# Data untuk "A vision of sustainable housing for all of humanity" berhasil dikirim.
# Data untuk ""Your Song" / "Real Life"" berhasil dikirim.
# Data untuk "3 ways to prepare society for the next pandemic" berhasil dikirim.
# Data untuk "The need for family reunification — to make families whole again" berhasil dikirim.
# Data untuk "Education is a fundamental right for every child" berhasil dikirim.
# Data untuk "The life-changing power of assistive technologies" berhasil dikirim.
# Data untuk "How to protect your mental well-being online — from a Gen-Zer" berhasil dikirim.
# Data untuk "A next-generation solution to climate crisis" berhasil dikirim.
# Data untuk ""Astral Plane"" berhasil dikirim.
# Data untuk "5 keys to shifting to a well-being economy — and the cost of inaction" berhasil dikirim.
# Data untuk "3 ways to lower the barriers to higher education" berhasil dikirim.
# Data untuk "How one of the most profitable companies in history rose to power" berhasil dikirim.
# Data untuk "How going to Mars improves life on Earth" berhasil dikirim.
# Data untuk "Africans should lead on health care solutions for Africa" berhasil dikirim.
# Data untuk "The end of Roe v. Wade — and what comes next for reproductive freedom" berhasil dikirim.
# Data untuk "4 steps to hiring fairly — and supporting criminal justice reform" berhasil dikirim.
# Data untuk "How sleep affects what (and how much) you eat" berhasil dikirim.
# Data untuk "Yes, scientists are actually building an elevator to space" berhasil dikirim.
# Data untuk "How to end the pandemic — and prepare for the next" berhasil dikirim.
# Data untuk "3 questions to build resilience — and change the world" berhasil dikirim.
# Data untuk "Community investment is the missing piece of climate action" berhasil dikirim.
# Data untuk "The dream of educating Afghan girls lives on" berhasil dikirim.
# Data untuk "How gratitude rewires your brain" berhasil dikirim.
# Data untuk "Can stereotypes ever be good?" berhasil dikirim.
# Data untuk "The value of kindness at work" berhasil dikirim.
# Data untuk "What is melatonin — and should you take it to fall asleep?" berhasil dikirim.
# Data untuk "The life cycle of a pair of jeans" berhasil dikirim.
# Data untuk "Is it really that bad to marry my cousin?" berhasil dikirim.
# Data untuk "It's impossible to have healthy people on a sick planet" berhasil dikirim.
# Data untuk "The surprising health benefits of dreaming" berhasil dikirim.
# Data untuk "Dear world leaders, these are our climate demands" berhasil dikirim.
# Data untuk "The science of extreme weather — and how to reduce the harm" berhasil dikirim.
# Data untuk "The wild sex lives of marine creatures" berhasil dikirim.
# Data untuk "The forest is our teacher. It's time to respect it" berhasil dikirim.
# Data untuk "How accurate is the weather forecast?" berhasil dikirim.
# Data untuk "An action plan for solving the climate crisis" berhasil dikirim.
# Data untuk "The science of preserving sight" berhasil dikirim.
# Data untuk "Can you solve the human cannonball riddle? " berhasil dikirim.
# Data untuk "Can climate change ever be funny? 17 comedians try to answer" berhasil dikirim.
# Data untuk "Your self-driving robotaxi is almost here" berhasil dikirim.
# Data untuk "Nature's fortress: How cacti keep water in and predators out" berhasil dikirim.
# Data untuk "A program to empower Black teachers in the US" berhasil dikirim.
# Data untuk "An ever-evolving map of everything on Earth" berhasil dikirim.
# Data untuk "Are naps actually good for us?" berhasil dikirim.
# Data untuk ""I Can See Clearly Now"" berhasil dikirim.
# Data untuk ""Back on My Feet"" berhasil dikirim.
# Data untuk "How to make a sad story funny" berhasil dikirim.
# Data untuk "The crucial intersection of climate and capital" berhasil dikirim.
# Data untuk "Which box do I check?" berhasil dikirim.
# Data untuk "3 steps to getting what you want in a negotiation" berhasil dikirim.
# Data untuk "Tracking the whole world's carbon emissions — with satellites and AI" berhasil dikirim.
# Data untuk "The rise of predatory scams — and how to prevent them" berhasil dikirim.
# Data untuk "The twins who tricked the Maya gods of death" berhasil dikirim.
# Data untuk ""Being Human"" berhasil dikirim.
# Data untuk "Leave only footprints that will wash away" berhasil dikirim.
# Data untuk "The many reasons to eat a plant-based diet" berhasil dikirim.
# Data untuk "The powerful women on the front lines of climate action" berhasil dikirim.
# Data untuk "A bold plan to protect 30 percent of the Earth's surface and ocean floor" berhasil dikirim.
# Data untuk "A vision for sustainable energy in Africa" berhasil dikirim.
# Data untuk "How your brain invents your "self"" berhasil dikirim.
# Data untuk "Why better sleep means a better sex life" berhasil dikirim.
# Data untuk "Why do some people snore so loudly?" berhasil dikirim.
# Data untuk "How small countries can make a big impact on climate change" berhasil dikirim.
# Data untuk "How did we get fertility so wrong?" berhasil dikirim.
# Data untuk "Super speed, magnetic levitation and the vision behind the hyperloop" berhasil dikirim.
# Data untuk "What working parents really need from workplaces" berhasil dikirim.
# Data untuk "The creative power of your intuition" berhasil dikirim.
# Data untuk "Are locust plagues unstoppable?" berhasil dikirim.
# Data untuk "A tailored history of who wears what — and why" berhasil dikirim.
# Data untuk "The problem of vaccine spoilage — and a smart sensor to help" berhasil dikirim.
# Data untuk "How daylight saving time affects our bodies, minds — and world" berhasil dikirim.
# Data untuk "How to make radical climate action the new normal" berhasil dikirim.
# Data untuk "How to get better at video games, according to babies" berhasil dikirim.
# Data untuk "What we miss when we focus on the average" berhasil dikirim.
# Data untuk "3 rules to help you build a successful business" berhasil dikirim.
# Data untuk "What is COP26?" berhasil dikirim.
# Data untuk "Countdown Global Livestream 2021" berhasil dikirim.
# Data untuk "The 55 gigaton challenge" berhasil dikirim.
# Data untuk "The haunting truth of ghost stories" berhasil dikirim.
# Data untuk "A new perspective on the journey to net-zero" berhasil dikirim.
# Data untuk "The fastest way to slow climate change now" berhasil dikirim.
# Data untuk "AI isn't as smart as you think — but it could be" berhasil dikirim.
# Data untuk "The Norse myth that inspired "The Lord of the Rings"" berhasil dikirim.
# Data untuk "How to turn around a city" berhasil dikirim.
# Data untuk "Stuck in the gig economy? Try platform co-ops instead" berhasil dikirim.
# Data untuk ""The [Uncertain] Four Seasons"" berhasil dikirim.
# Data untuk "The surprisingly long history of electric cars" berhasil dikirim.
# Data untuk "Can China achieve its ambitious climate pledges?" berhasil dikirim.
# Data untuk "Do 9 out of 10 dentists really recommend that toothpaste?" berhasil dikirim.
# Data untuk "What to expect from COP26" berhasil dikirim.
# Data untuk "Visions for the future" berhasil dikirim.
# Data untuk "How to reduce bias in your workplace" berhasil dikirim.
# Data untuk "3 tips for leaders to get the future of work right " berhasil dikirim.
# Data untuk "How your nature photos can help protect wild animals" berhasil dikirim.
# Data untuk "Why is this 2,500 year old shipwreck so well-preserved?" berhasil dikirim.
# Data untuk "A close-to-home solution for accessible childcare" berhasil dikirim.
# Data untuk "What makes a friendship last? " berhasil dikirim.
# Data untuk "How much clean electricity do we really need?" berhasil dikirim.
# Data untuk "Can you solve the risky disk riddle?" berhasil dikirim.
# Data untuk "How we could eat real meat without harming animals" berhasil dikirim.
# Data untuk "How long does it take to get over a breakup?" berhasil dikirim.
# Data untuk "The small business hustle" berhasil dikirim.
# Data untuk "Why don't we cover the desert with solar panels?" berhasil dikirim.
# Data untuk "Why paternity leave benefits everyone" berhasil dikirim.
# Data untuk "Introducing: Am I Normal? with Mona Chalabi" berhasil dikirim.
# Data untuk "The bad math of the fossil fuel industry" berhasil dikirim.
# Data untuk "Decarbonizing fossil fuels" berhasil dikirim.
# Data untuk "Can love and independence coexist?" berhasil dikirim.
# Data untuk "Why skin disease is often misdiagnosed in darker skin tones" berhasil dikirim.
# Data untuk "What you discover when you really listen" berhasil dikirim.
# Data untuk "The billion-dollar campaign to electrify transport" berhasil dikirim.
# Data untuk "A roadmap for young changemakers" berhasil dikirim.
# Data untuk "¿Por qué nos cuesta mirarnos al espejo? | Andrea Vilallonga | TEDxTarragona" berhasil dikirim.
# Data untuk "Where will you be able to live in 20 years?" berhasil dikirim.
# Data untuk "Relief to recovery" berhasil dikirim.
# Data untuk "5 tips for dealing with meeting overload" berhasil dikirim.
# Data untuk "How humanity doubled life expectancy in a century" berhasil dikirim.
# Data untuk "What happened to the lost Kingdom of Kush?" berhasil dikirim.
# Data untuk "A more accurate way to calculate emissions" berhasil dikirim.
# Data untuk "The brain science of obesity" berhasil dikirim.
# Data untuk "The genes you don't get from your parents (but can't live without)" berhasil dikirim.
# Data untuk "How NFTs are building the internet of the future" berhasil dikirim.
# Data untuk "Want to truly succeed? Lift others up while you climb" berhasil dikirim.
# Data untuk "3 ways community creates a healthy life" berhasil dikirim.
# Data untuk "Ancient Greece's greatest popstar" berhasil dikirim.
# Data untuk "The Black history of twerking — and how it taught me self-love" berhasil dikirim.
# Data untuk "Why the passport needs an upgrade" berhasil dikirim.
# Data untuk "How employers steal from workers — and get away with it" berhasil dikirim.
# Data untuk "The forgotten queen of Egypt" berhasil dikirim.
# Data untuk "3 rules for better work-life balance" berhasil dikirim.
# Data untuk "Could you recover from illness ... using your own stem cells?" berhasil dikirim.
# Data untuk "Can you solve the rogue submarine riddle? Difficulty level: Master" berhasil dikirim.
# Data untuk "The art of paying attention" berhasil dikirim.
# Data untuk "The intended consequences of helping nature thrive" berhasil dikirim.
# Data untuk "The secrets of the world's most famous symphony" berhasil dikirim.
# Data untuk "The link between inequality and anxiety" berhasil dikirim.
# Data untuk "Planet City — a sci-fi vision of an astonishing regenerative future" berhasil dikirim.
# Data untuk "The untapped energy source that could power the planet" berhasil dikirim.
# Data untuk "You could have a secret twin (but not the way you think)" berhasil dikirim.
# Data untuk "An NFL quarterback on overcoming setbacks and self-doubt" berhasil dikirim.
# Data untuk "The trans story includes you" berhasil dikirim.
# Data untuk "The inaccurate link between body ideals and health" berhasil dikirim.
# Data untuk "Earth's mysterious red glow, explained" berhasil dikirim.
# Data untuk "A smart bra for better heart health" berhasil dikirim.
# Data untuk "Life-altering questions about the end of the universe" berhasil dikirim.
# Data untuk "What makes a language... a language?" berhasil dikirim.
# Data untuk "The big myth of government deficits" berhasil dikirim.
# Data untuk "A sci-fi vision of life in 2041" berhasil dikirim.
# Data untuk "The rise and fall of the Lakota Empire " berhasil dikirim.
# Data untuk "How to stop languishing and start finding flow" berhasil dikirim.
# Data untuk "A new way to restore Earth's biodiversity — from the air" berhasil dikirim.
# Data untuk "What is MSG, and is it actually bad for you?" berhasil dikirim.
# Data untuk "The state of the climate crisis in 2021" berhasil dikirim.
# Data untuk "A taste of Mexico's ancient chocolate-making tradition" berhasil dikirim.
# Data untuk "The infamous overpopulation bet: Simon vs. Ehrlich" berhasil dikirim.
# Data untuk "How music can help you find peace after loss" berhasil dikirim.
# Data untuk "A future with fewer cars" berhasil dikirim.
# Data untuk "Is this the most successful animal ever?" berhasil dikirim.
# Data untuk "How we can detect pretty much anything" berhasil dikirim.
# Data untuk "Can you outsmart the slippery slope fallacy?" berhasil dikirim.
# Data untuk "How the COVID-19 vaccines were created so quickly" berhasil dikirim.
# Data untuk "The secret society of the Great Dismal Swamp" berhasil dikirim.
# Data untuk "Walk with Little Amal, a theatrical journey celebrating the refugee experience" berhasil dikirim.
# Data untuk "How COVID-19 reshaped US cities" berhasil dikirim.
# Data untuk "Can you solve the giant spider riddle?" berhasil dikirim.
# Data untuk "An interactive map to track (and end) pollution in China" berhasil dikirim.
# Data untuk "Why are stolen African artifacts still in Western museums?" berhasil dikirim.
# Data untuk "The fingerprints of life beyond Earth" berhasil dikirim.
# Data untuk "The method that can "prove" almost anything" berhasil dikirim.
# Data untuk "The tiny balls of fat that could revolutionize medicine" berhasil dikirim.
# Data untuk "Don't call people out — call them in" berhasil dikirim.
# Data untuk "What causes seizures, and how can we treat them?" berhasil dikirim.
# Data untuk "Meet the scientist couple driving an mRNA vaccine revolution" berhasil dikirim.
# Data untuk "Remembering climate change ... a message from the year 2071" berhasil dikirim.
# Data untuk "The informal settlements reshaping the world " berhasil dikirim.
# Data untuk "Iceland's superpowered underground volcanoes" berhasil dikirim.
# Data untuk "The radical, revolutionary resilience of Black joy" berhasil dikirim.
# Data untuk "A year in the life of one of Earth's weirdest animals" berhasil dikirim.
# Data untuk "3 rules for a zero-carbon world" berhasil dikirim.
# Data untuk "The ancient origins of the Olympics" berhasil dikirim.
# Data untuk "The rise and fall of the Kingdom of Man" berhasil dikirim.
# Data untuk "Are wild animals really "wild"?" berhasil dikirim.
# Data untuk "How every child can thrive by five" berhasil dikirim.
# Data untuk "The paradox at the heart of mathematics: Gödel's Incompleteness Theorem" berhasil dikirim.
# Data untuk "The (de)colonizing of beauty" berhasil dikirim.
# Data untuk "Why COP26 is our best chance for a greener future" berhasil dikirim.
# Data untuk "3 myths about racism that keep the US from progress" berhasil dikirim.
# Data untuk "How do governments create money out of thin air?" berhasil dikirim.
# Data untuk "The missing 96 percent of the universe" berhasil dikirim.
# Data untuk "The most notorious scientific feud in history" berhasil dikirim.
# Data untuk "The link between menopause and gender inequity at work" berhasil dikirim.
# Data untuk "Documentary films that explore trauma — and make space for healing" berhasil dikirim.
# Data untuk "History's deadliest king" berhasil dikirim.
# Data untuk "A cleanse won't detox your body — but here's what will" berhasil dikirim.
# Data untuk "What should humans take to space (and leave behind)?" berhasil dikirim.
# Data untuk "Could we build a wooden skyscraper?" berhasil dikirim.
# Data untuk "Why aren't there more Native American restaurants?" berhasil dikirim.
# Data untuk "How music streaming transformed songwriting" berhasil dikirim.
# Data untuk "What's normal anxiety — and what's an anxiety disorder?" berhasil dikirim.
# Data untuk "The dark history of the Chinese Exclusion Act" berhasil dikirim.
# Data untuk "What if we saw climate change as an amazing challenge, not a burden?" berhasil dikirim.
# Data untuk "The infinite alchemy of storytelling" berhasil dikirim.
# Data untuk "How to turn grit into a lifelong habit | Angela Duckworth" berhasil dikirim.
# Data untuk "Why we're more honest with machines than people" berhasil dikirim.
# Data untuk "Real-life "Alien" jaws" berhasil dikirim.
# Data untuk "How one person saved over 2,000 children from the Nazis" berhasil dikirim.
# Data untuk "How to heat your home without hurting the planet" berhasil dikirim.
# Data untuk "What to do when climate change feels unstoppable" berhasil dikirim.
# Data untuk "Can you cheat death by solving this riddle?" berhasil dikirim.
# Data untuk "5 skin health myths to stop believing now" berhasil dikirim.
# Data untuk "The life-saving tech helping mothers make healthy decisions" berhasil dikirim.
# Data untuk "These salamanders snack on each other (but don't die)" berhasil dikirim.
# Data untuk "The search for microscopic aliens" berhasil dikirim.
# Data untuk "Why was India split into two countries?" berhasil dikirim.
# Data untuk "The emotions behind your money habits" berhasil dikirim.
# Data untuk "How marijuana reform could repair, reclaim and restore communities" berhasil dikirim.
# Data untuk "What few people know about the program that "saved" America" berhasil dikirim.
# Data untuk "Can you actually boost your immune system? Here's the truth" berhasil dikirim.
# Data untuk "A new approach to defending the human rights of migrants" berhasil dikirim.
# Data untuk "How to find meaning after loss" berhasil dikirim.
# Data untuk "A brief history of toilets" berhasil dikirim.
# Data untuk "How to be a professional troublemaker" berhasil dikirim.
# Data untuk "An app that empowers people to solve their legal problems" berhasil dikirim.
# Data untuk "The sharks that hunt in forests" berhasil dikirim.
# Data untuk "A queer journey from shame to self-love" berhasil dikirim.
# Data untuk "The real-life superheroes helping Syrian refugees" berhasil dikirim.
# Data untuk "How do you know what's true?" berhasil dikirim.
# Data untuk "Why healthy bones are about so much more than milk" berhasil dikirim.
# Data untuk "How to reduce your diet's carbon footprint — without going vegan" berhasil dikirim.
# Data untuk "A feminist reimagining of Kenya's public transport" berhasil dikirim.
# Data untuk "Ugly History: The US syphilis experiment" berhasil dikirim.
# Data untuk "How to support yourself (and others) through grief" berhasil dikirim.
# Data untuk "How your body could become its own diagnostic lab" berhasil dikirim.
# Data untuk "A day in the life of the Oracle of Delphi" berhasil dikirim.
# Data untuk "The multibillion-dollar US prison industry — and how to dismantle it" berhasil dikirim.
# Data untuk "The anxiety that comes from being treated like an outsider" berhasil dikirim.
# Data untuk "Why do we have hair in such random places?" berhasil dikirim.
# Data untuk "What really happens to your body during menopause" berhasil dikirim.
# Data untuk "Essential questions to ask your future self" berhasil dikirim.
# Data untuk "Who makes judges?" berhasil dikirim.
# Data untuk "The epic of Gilgamesh, the king who tried to conquer death" berhasil dikirim.
# Data untuk "Playful, wondrous public spaces built for community and possibility" berhasil dikirim.
# Data untuk "The rigged test of leadership" berhasil dikirim.
# Data untuk "Tips for reclaiming your peace of mind online" berhasil dikirim.
# Data untuk "Can you solve the Trojan War riddle?" berhasil dikirim.
# Data untuk "Why you shouldn't worry about pooping once a day" berhasil dikirim.
# Data untuk "How dirt bikes and STEM ignite ingenuity in Baltimore" berhasil dikirim.
# Data untuk "What farmers need to be modern, climate-friendly and profitable" berhasil dikirim.
# Data untuk "Could you survive the real Twilight Zone?" berhasil dikirim.
# Data untuk "Electronic pills that could transform how we treat disease" berhasil dikirim.
# Data untuk "The woman who stared at the sun" berhasil dikirim.
# Data untuk "The death of the universe — and what it means for life" berhasil dikirim.
# Data untuk "The cure for burnout (hint: it isn't self-care)" berhasil dikirim.
# Data untuk "Run, sail or hide? How to survive the destruction of Pompeii" berhasil dikirim.
# Data untuk "Why you don't need 8 glasses of water a day" berhasil dikirim.
# Data untuk "How NASA invented a ventilator for COVID-19 ... in 37 days" berhasil dikirim.
# Data untuk "Can you be awake and asleep at the same time?" berhasil dikirim.
# Data untuk "The best career path isn't always a straight line" berhasil dikirim.
# Data untuk "What happens to your brain during a migraine?" berhasil dikirim.
# Data untuk "Better cybersecurity starts with honesty and accountability" berhasil dikirim.
# Data untuk "Introducing Body Stuff with Dr. Jen Gunter" berhasil dikirim.
# Data untuk "The science behind how parents affect child development" berhasil dikirim.
# Data untuk "How to discover your "why" in difficult times" berhasil dikirim.
# Data untuk "The case for co-ops, the invisible giant of the economy" berhasil dikirim.
# Data untuk "What really happened during the Attica Prison Rebellion" berhasil dikirim.
# Data untuk "What's the difference between guilt and shame?" berhasil dikirim.
# Data untuk "What's in the air you breathe?" berhasil dikirim.
# Data untuk "How COVID-19 transformed the future of medicine" berhasil dikirim.
# Data untuk "What's your happiness score?" berhasil dikirim.
# Data untuk "How one design flaw almost toppled a skyscraper" berhasil dikirim.
# Data untuk "Why children of immigrants experience guilt — and strategies to cope" berhasil dikirim.
# Data untuk "The future of flying is electrifying" berhasil dikirim.
# Data untuk "Who decides what's in the dictionary?" berhasil dikirim.
# Data untuk "7 tools for building a business people trust" berhasil dikirim.
# Data untuk "Meet the bluefin tuna, the toughest fish in the sea" berhasil dikirim.
# Data untuk "Women and girls, you are part of the climate solution" berhasil dikirim.
# Data untuk "How long should your naps be?" berhasil dikirim.
# Data untuk "What frogs in hot water can teach us about thinking again" berhasil dikirim.
# Data untuk "Cities are driving climate change. Here's how they can fix it" berhasil dikirim.
# Data untuk "Demolition, disease, and death: Building the Panama Canal" berhasil dikirim.
# Data untuk "The intergenerational wisdom woven into Indigenous stories" berhasil dikirim.
# Data untuk "To accomplish great things, you need to "let the paint dry"" berhasil dikirim.
# Data untuk "Can you solve Dongle's Difficult Dilemma?" berhasil dikirim.
# Data untuk "The revolutionary power of Black joy" berhasil dikirim.
# Data untuk "The race to build AI that benefits humanity with Sam Altman" berhasil dikirim.
# Data untuk "How do wind turbines work?" berhasil dikirim.
# Data untuk "3 strategies for effectively talking about climate change" berhasil dikirim.
# Data untuk "How your memory works — and why forgetting is totally OK" berhasil dikirim.
# Data untuk "How the world's tallest skyscraper was built" berhasil dikirim.
# Data untuk "The world's most painful insect sting" berhasil dikirim.
# Data untuk "The global cooperation that accelerated the COVID-19 vaccines" berhasil dikirim.
# Data untuk "Earth's original inhabitants — and their role in combating climate change" berhasil dikirim.
# Data untuk "Can we learn to talk to sperm whales?" berhasil dikirim.
# Data untuk "Why are airplanes slower than they used to be?" berhasil dikirim.
# Data untuk "I am not your Asian stereotype" berhasil dikirim.
# Data untuk "Why corporate diversity programs fail — and how small tweaks can have big impact" berhasil dikirim.
# Data untuk "A NASA astronaut's lessons on fear, confidence and preparing for spaceflight" berhasil dikirim.
# Data untuk "Whatever happened to acid rain?" berhasil dikirim.
# Data untuk "4 myths and misunderstandings about doing business in Africa" berhasil dikirim.
# Data untuk "This tool will help improve your critical thinking" berhasil dikirim.
# Data untuk "The giant leaps in language technology — and who's left behind" berhasil dikirim.
# Data untuk "Mantua Townshi‪p‬" berhasil dikirim.
# Data untuk "The surprising secrets of hummingbird flight" berhasil dikirim.
# Data untuk "How we can curb climate change by spending two percent more on everything" berhasil dikirim.
# Data untuk "The routines, rituals and boundaries we need in stressful times" berhasil dikirim.
# Data untuk "Why good ideas get trapped in the valley of death — and how to rescue them" berhasil dikirim.
# Data untuk " US politics isn't broken. It's fixed" berhasil dikirim.
# Data untuk "Can you outsmart the apples and oranges fallacy?" berhasil dikirim.
# Data untuk "The exploitation of US college athletes" berhasil dikirim.
# Data untuk "Step 1: The Puls‪e‬" berhasil dikirim.
# Data untuk "How does ultrasound work?" berhasil dikirim.
# Data untuk "An honest history of an ancient and "nasty" word" berhasil dikirim.
# Data untuk "The electrical blueprints that orchestrate life" berhasil dikirim.
# Data untuk "Language around gender and identity evolves (and always has)" berhasil dikirim.
# Data untuk "Why every world map is wrong" berhasil dikirim.
# Data untuk "A brief history of the devil" berhasil dikirim.
# Data untuk "The seeds of change helping African farmers grow out of poverty" berhasil dikirim.
# Data untuk "What science taught me about being a Muslim drag quee‪n‬" berhasil dikirim.
# Data untuk "Can you solve the fantasy election riddle?" berhasil dikirim.
# Data untuk "An election system that puts voters (not politicians) first" berhasil dikirim.
# Data untuk "Why I photograph the quiet moments of grief and loss" berhasil dikirim.
# Data untuk "Ugly History: The Spanish Inquisition" berhasil dikirim.
# Data untuk "Possible futures from the intersection of nature, tech and society" berhasil dikirim.
# Data untuk "What's the best fuel for your car?" berhasil dikirim.
# Data untuk "The innovations we need to avoid a climate disaster" berhasil dikirim.
# Data untuk "The Power of Spaces" berhasil dikirim.
# Data untuk "How do antidepressants work?" berhasil dikirim.
# Data untuk "Online learning could change academia — for good" berhasil dikirim.
# Data untuk "How to have constructive conversations" berhasil dikirim.
# Data untuk "How much land does it take to power the world?" berhasil dikirim.
# Data untuk "How synthetic biology can improve our health, food and materials" berhasil dikirim.
# Data untuk "The incredible, bendable, twistable, expandable elephant trunk" berhasil dikirim.
# Data untuk "What if mental health workers responded to emergency calls?" berhasil dikirim.
# Data untuk "How to challenge conventional wisdom — and change any industry" berhasil dikirim.
# Data untuk "4 lessons the pandemic taught us about work, life and balance" berhasil dikirim.
# Data untuk "How does artificial intelligence learn?" berhasil dikirim.
# Data untuk "What is deep tech? A look at how it could shape the future" berhasil dikirim.
# Data untuk "Love, sorrow and the emotions that power climate action" berhasil dikirim.
# Data untuk "How much electricity does it take to power the world?" berhasil dikirim.
# Data untuk "Who were Las Mariposas, and why were they murdered?" berhasil dikirim.
# Data untuk "The myth of bringing your full, authentic self to work" berhasil dikirim.
# Data untuk "Brené Brown on What Vulnerability Isn't" berhasil dikirim.
# Data untuk "Should we cry at work?" berhasil dikirim.
# Data untuk "How would you finish the sentence, "Imagine if..."?" berhasil dikirim.
# Data untuk "Climate change is our reality. Here's how we're taking action" berhasil dikirim.
# Data untuk "My mother's final wish — and the right to die with dignity" berhasil dikirim.
# Data untuk "10 steps to boost your financial health — that you can do in a day" berhasil dikirim.
# Data untuk "Can loud music damage your hearing?" berhasil dikirim.
# Data untuk "How compassion could save your strained relationships" berhasil dikirim.
# Data untuk "The material that could change the world ... for a third time" berhasil dikirim.
# Data untuk "How video game skills can get you ahead in life" berhasil dikirim.
# Data untuk "Cheryl Strayed" berhasil dikirim.
# Data untuk "Debunking the myth of the Lost Cause: A lie embedded in American history" berhasil dikirim.
# Data untuk "The value of your humanity in an automated future" berhasil dikirim.
# Data untuk "The people who caused the climate crisis aren't the ones who will fix it" berhasil dikirim.
# Data untuk "Why talking to your friends can help you save money" berhasil dikirim.
# Data untuk "Can you solve the logician's rave riddle?" berhasil dikirim.
# Data untuk "Why there's no such thing as objective reality" berhasil dikirim.
# Data untuk "The world's biggest battery looks nothing like a battery" berhasil dikirim.
# Data untuk ""Aliens built the pyramids" and other absurdities of pseudo-archaeology" berhasil dikirim.
# Data untuk "Brené Brown" berhasil dikirim.
# Data untuk "The Trans Ban" berhasil dikirim.
# Data untuk "The US is back in the Paris Agreement. What's next?" berhasil dikirim.
# Data untuk "Why do we, like, hesitate when we, um, speak?" berhasil dikirim.
# Data untuk "Meditations on the intersection of humanity and technology" berhasil dikirim.
# Data untuk "How theater weathers wars, outlasts empires and survives pandemics" berhasil dikirim.
# Data untuk "3 sneaky tactics that websites use to make you spend" berhasil dikirim.
# Data untuk "The "myth" of the boiling frog" berhasil dikirim.
# Data untuk "I let algorithms randomize my life for two years" berhasil dikirim.
# Data untuk "The unexpected math of origami" berhasil dikirim.
# Data untuk "The hidden history found in your teeth" berhasil dikirim.
# Data untuk "5 steps to designing the life you want " berhasil dikirim.
# Data untuk "We're experiencing an empathy shortage, but we can fix it together" berhasil dikirim.
# Data untuk "Technology can't fix inequality — but training and opportunities could" berhasil dikirim.
# Data untuk "Community-powered solutions to the climate crisis" berhasil dikirim.
# Data untuk "A simple 2-step plan for saving more money" berhasil dikirim.
# Data untuk "The promise of quantum computers" berhasil dikirim.
# Data untuk "What causes dandruff, and how do you get rid of it?" berhasil dikirim.
# Data untuk "The artist who won a Nobel Prize... in medicine" berhasil dikirim.
# Data untuk "A concrete idea to reduce carbon emissions" berhasil dikirim.
# Data untuk "How to get everyone to care about a green economy" berhasil dikirim.
# Data untuk "Why didn't this 2,000 year old body decompose?" berhasil dikirim.
# Data untuk "How technology changes our sense of right and wrong" berhasil dikirim.
# Data untuk "TikTok, Instagram, Snapchat — and the rise of bite-sized content" berhasil dikirim.
# Data untuk "Pay off your credit cards faster with these 4 easy changes" berhasil dikirim.
# Data untuk "What if every satellite suddenly disappeared?" berhasil dikirim.
# Data untuk "How a geospatial nervous system could help us design a better future" berhasil dikirim.
# Data untuk "The world's most dangerous fart" berhasil dikirim.
# Data untuk "When the world is burning, is art a waste of time?" berhasil dikirim.
# Data untuk "How to avoid catching prickly emotions from other people " berhasil dikirim.
# Data untuk ""Fearless"" berhasil dikirim.
# Data untuk "Why bats don't get sick" berhasil dikirim.
# Data untuk "A brief history of divorce" berhasil dikirim.
# Data untuk "A stealthy reimagining of urban public space" berhasil dikirim.
# Data untuk "What COVID-19 revealed about US schools — and 4 ways to rethink education" berhasil dikirim.
# Data untuk "Can't stick to a budget? Try these tweaks instead" berhasil dikirim.
# Data untuk "The joy of shopping — and how to recapture it online" berhasil dikirim.
# Data untuk "The Japanese myth of the trickster raccoon" berhasil dikirim.
# Data untuk "The 15-minute city" berhasil dikirim.
# Data untuk "The case for public media" berhasil dikirim.
# Data untuk "My journey mapping the uncharted world" berhasil dikirim.
# Data untuk "The rise of the Ottoman Empire" berhasil dikirim.
# Data untuk "How vulnerability makes you a better leader" berhasil dikirim.
# Data untuk "Who decides how long a second is?" berhasil dikirim.
# Data untuk ""The Hill We Climb"" berhasil dikirim.
# Data untuk "3 ways to upgrade democracy for the 21st century" berhasil dikirim.
# Data untuk "The money talk that every couple needs to have" berhasil dikirim.
# Data untuk "How a strong creative industry helps economies thrive" berhasil dikirim.
# Data untuk "Our moral imperative to act on climate change — and 3 steps we can take (English voiceover)" berhasil dikirim.
# Data untuk "Nuestro imperativo moral para actuar sobre el cambio climático — y 3 pasos que podemos dar" berhasil dikirim.
# Data untuk "How bad data keeps us from good AI" berhasil dikirim.
# Data untuk "How your brain responds to stories — and why they're crucial for leaders" berhasil dikirim.
# Data untuk "Savitri and Satyavan: The legend of the princess who outwitted Death" berhasil dikirim.
# Data untuk "4 tips to kickstart honest conversations at work" berhasil dikirim.
# Data untuk "Why we make bad financial choices — even when we know better" berhasil dikirim.
# Data untuk "Humanity's planet-shaping powers — and what they mean for the future" berhasil dikirim.
# Data untuk "How carbon capture networks could help curb climate change" berhasil dikirim.
# Data untuk "These squids can fly... no, really" berhasil dikirim.
# Data untuk "6 essential lessons for women leaders " berhasil dikirim.
# Data untuk "How AI can help shatter barriers to equality" berhasil dikirim.
# Data untuk ""TRY"" berhasil dikirim.
# Data untuk "A day in the life of an ancient Babylonian business mogul" berhasil dikirim.
# Data untuk "The 1-minute secret to forming a new habit" berhasil dikirim.
# Data untuk "How to turn moments into momentum" berhasil dikirim.
# Data untuk "The counterintuitive way to be more persuasive" berhasil dikirim.
# Data untuk "Why should you read Toni Morrison's "Beloved"?" berhasil dikirim.
# Data untuk "3 ways companies can support grieving employees" berhasil dikirim.
# Data untuk "The life cycle of a cup of coffee" berhasil dikirim.
# Data untuk "How we could make carbon-negative concrete" berhasil dikirim.
# Data untuk "How do personality tests work?" berhasil dikirim.
# Data untuk "The strange history of the world's most stolen painting" berhasil dikirim.
# Data untuk "How we can actually pay people enough — with Paypal CEO Dan Schulman" berhasil dikirim.
# Data untuk "6 big ethical questions about the future of AI " berhasil dikirim.
# Data untuk "The shadow pandemic of domestic violence during COVID-19" berhasil dikirim.
# Data untuk "3 bizarre (and delightful) ancient theories about bird migration" berhasil dikirim.
# Data untuk "Financial inclusion, the digital divide and other thoughts on the future of money" berhasil dikirim.
# Data untuk "What happens when you die? A poetic inquiry" berhasil dikirim.
# Data untuk "Who counts as a speaker of a language?" berhasil dikirim.
# Data untuk "What your sleep patterns say about your relationship" berhasil dikirim.
# Data untuk "An innovative way to support children with special needs" berhasil dikirim.
# Data untuk "Can you win a game of quantum foosball?" berhasil dikirim.
# Data untuk "How to be an upstander instead of a bystander" berhasil dikirim.
# Data untuk "A strategy for supporting and listening to others" berhasil dikirim.
# Data untuk "Building the world's largest (and most controversial) power plant" berhasil dikirim.
# Data untuk "Why monkeys (and humans) are wired for fairness" berhasil dikirim.
# Data untuk "How creative writing can help you through life's hardest moments" berhasil dikirim.
# Data untuk "Can you solve the monster duel riddle?" berhasil dikirim.
# Data untuk "The legacy of matriarchs in the Yukon First Nations" berhasil dikirim.
# Data untuk "The world's largest organism" berhasil dikirim.
# Data untuk "The end of globalization (and the beginning of something new)" berhasil dikirim.
# Data untuk "Fossil fuel companies know how to stop global warming. Why don't they?" berhasil dikirim.
# Data untuk "A stellar history of modern astronomy" berhasil dikirim.
# Data untuk "Easy ways to practice empathy in your own life" berhasil dikirim.
# Data untuk "The most colorful gemstones on Earth" berhasil dikirim.
# Data untuk "How to foster true diversity and inclusion at work (and in your community)" berhasil dikirim.
# Data untuk "An aerialist on listening to your body's signals" berhasil dikirim.
# Data untuk "The myth of Loki and the deadly mistletoe" berhasil dikirim.
# Data untuk "It takes a community to eradicate hate" berhasil dikirim.
# Data untuk "Inside the massive (and unregulated) world of surveillance tech" berhasil dikirim.
# Data untuk "Why is pneumonia so dangerous?" berhasil dikirim.
# Data untuk "The city planting a million trees in two years" berhasil dikirim.
# Data untuk "How to come out at work, about anything" berhasil dikirim.
# Data untuk "A chef shares: Here's how we can feed the planet without hurting the climate " berhasil dikirim.
# Data untuk "How reverse mentorship can help create better leaders" berhasil dikirim.
# Data untuk "How COVID-19 human challenge trials work — and why I volunteered" berhasil dikirim.
# Data untuk "Could we treat spinal cord injuries with asparagus?" berhasil dikirim.
# Data untuk "Which bag should you use?" berhasil dikirim.
# Data untuk "How quinoa can help combat hunger and malnutrition" berhasil dikirim.
# Data untuk "A playful exploration of gender performance" berhasil dikirim.
# Data untuk "Can you solve the Alice in Wonderland riddle?" berhasil dikirim.
# Data untuk "What it takes to crush a pandemic" berhasil dikirim.
# Data untuk "The mood-boosting power of crying" berhasil dikirim.
# Data untuk "A magical mantra for nurturing a blissful life" berhasil dikirim.
# Data untuk "Virtual Worlds" berhasil dikirim.
# Data untuk "How fast is the speed of thought?" berhasil dikirim.
# Data untuk "How India could pull off the world's most ambitious energy transition" berhasil dikirim.
# Data untuk ""Shadow"" berhasil dikirim.
# Data untuk "How working couples can best support each other" berhasil dikirim.
# Data untuk "How the new generation of Latinx voters could change US elections" berhasil dikirim.
# Data untuk "To future generations of women, you are the roots of change" berhasil dikirim.
# Data untuk "Why do you get a fever when you're sick?" berhasil dikirim.
# Data untuk "How to be fearless in the face of authoritarianism" berhasil dikirim.
# Data untuk "How a world-record mountaineer empowers youth to overcome fear" berhasil dikirim.
# Data untuk "What female military leadership can teach us about overcoming self-doubt" berhasil dikirim.
# Data untuk "How do investors choose stocks?" berhasil dikirim.
# Data untuk "To save the climate, we have to reimagine capitalism" berhasil dikirim.
# Data untuk "Theranos, whistleblowing and speaking truth to power" berhasil dikirim.
# Data untuk "How do steroids affect your muscles— and the rest of your body?" berhasil dikirim.
# Data untuk "The energy Africa needs to develop — and fight climate change" berhasil dikirim.
# Data untuk "How we can use the hiring process to bring out the best in people" berhasil dikirim.
# Data untuk "The world is running out of water — but new tech can help" berhasil dikirim.
# Data untuk "I stepped out of grief — by dancing with fire" berhasil dikirim.
# Data untuk "Do larger animals take longer to pee?" berhasil dikirim.
# Data untuk "Lessons on leaving the world better than you found it" berhasil dikirim.
# Data untuk "24 hours on Earth — in one image" berhasil dikirim.
# Data untuk "The dark history of bananas" berhasil dikirim.
# Data untuk "The radical act of choosing common ground" berhasil dikirim.
# Data untuk "How your unique story can get you hired" berhasil dikirim.
# Data untuk "What crows teach us about death" berhasil dikirim.
# Data untuk "The race to net-zero emissions by 2050 is on. Can we count you in?" berhasil dikirim.
# Data untuk "How to foster productive and responsible debate" berhasil dikirim.
# Data untuk "How to decarbonize the grid and electrify everything" berhasil dikirim.
# Data untuk "Can you outsmart a troll (by thinking like one)?" berhasil dikirim.
# Data untuk "The case for stubborn optimism on climate" berhasil dikirim.
# Data untuk "The power of venom — and how it could one day save your life" berhasil dikirim.
# Data untuk "What the Irish wake teaches us about living and dying" berhasil dikirim.
# Data untuk "What if there were 1 trillion more trees?" berhasil dikirim.
# Data untuk "Climate change is becoming a problem you can taste" berhasil dikirim.
# Data untuk "Can you outsmart the fallacy that started a witch hunt?" berhasil dikirim.
# Data untuk "What if a US presidential candidate refuses to concede after an election?" berhasil dikirim.
# Data untuk "Can we create vaccines that mutate and spread?" berhasil dikirim.
# Data untuk "How to lead in a crisis" berhasil dikirim.
# Data untuk "On time and water" berhasil dikirim.
# Data untuk "How to reduce the wealth gap between Black and white Americans" berhasil dikirim.
# Data untuk "How to be a good ancestor" berhasil dikirim.
# Data untuk "An Indigenous Mixtape from Lima, Peru" berhasil dikirim.
# Data untuk "Why children stay silent following sexual violence" berhasil dikirim.
# Data untuk "The hidden treasures of Timbuktu" berhasil dikirim.
# Data untuk "What it takes to create social change against all odds" berhasil dikirim.
# Data untuk "Could CBD help opioid users overcome addiction?" berhasil dikirim.
# Data untuk "Which type of milk is best for you?" berhasil dikirim.
# Data untuk "Apple's promise to be carbon neutral by 2030" berhasil dikirim.
# Data untuk "How businesses can serve everyone, not just shareholders" berhasil dikirim.
# Data untuk "Could we harness the power of a black hole?" berhasil dikirim.
# Data untuk "Amazon's climate pledge to be net-zero by 2040" berhasil dikirim.
# Data untuk "The secret to being a successful freelancer" berhasil dikirim.
# Data untuk "The race to a zero-emission world starts now	" berhasil dikirim.
# Data untuk "The global movement to restore nature's biodiversity" berhasil dikirim.
# Data untuk "Make your actions on climate reflect your words	" berhasil dikirim.
# Data untuk "Countdown Session 5: Action (Full session)" berhasil dikirim.
# Data untuk "Countdown Session 4: Transformation (Full session)" berhasil dikirim.
# Data untuk "Countdown Session 3: Transformation (Full session)" berhasil dikirim.
# Data untuk "Countdown Session 2: Leadership (Full session)" berhasil dikirim.
# Data untuk "Countdown Session 1: Urgency (Full session)" berhasil dikirim.
# ...
# Data untuk "My year of living biblically" berhasil dikirim.
# Data untuk "On technology and faith" berhasil dikirim.
# Data untuk "The brain in love" berhasil dikirim.
# Data untuk "Let's look for life in the outer solar system" berhasil dikirim.
# Data untuk ""Mother of Pearl," "If I Had You"" berhasil dikirim.
# Data untuk "Institutions vs. collaboration" berhasil dikirim.
# Data untuk "What happens when you lose everything" berhasil dikirim.
# Data untuk "Animate characters by evolving them" berhasil dikirim.
# Data untuk "A hero of the Congo forest" berhasil dikirim.
# Data untuk ""Peace on Earth"" berhasil dikirim.
# Data untuk "The story of a girl" berhasil dikirim.
# Data untuk "Stephen Hawking's zero g flight" berhasil dikirim.
# Data untuk "A performance with breath, music, passion" berhasil dikirim.
# Data untuk ""Clonie"" berhasil dikirim.
# Data untuk "One Laptop per Child, two years on" berhasil dikirim.
# Data untuk "The transformative power of classical music" berhasil dikirim.
# Data untuk "Surprising stats about child carseats" berhasil dikirim.
# Data untuk "A mobile fridge for vaccines" berhasil dikirim.
# Data untuk "Robots inspired by cockroach ingenuity" berhasil dikirim.
# Data untuk "Your genes are not your fate" berhasil dikirim.
# Data untuk "Turning powerful stats into art" berhasil dikirim.
# Data untuk "The birth of the computer" berhasil dikirim.
# Data untuk "The ancestor of language" berhasil dikirim.
# Data untuk "The worldwide web of belief and ritual" berhasil dikirim.
# Data untuk ""Kounandi"" berhasil dikirim.
# Data untuk "Archaeology, animal photography, BBQ ..." berhasil dikirim.
# Data untuk "Memes and "temes"" berhasil dikirim.
# Data untuk "The "bottom billion"" berhasil dikirim.
# Data untuk "A hospital tour in Nigeria" berhasil dikirim.
# Data untuk "Moving sculpture" berhasil dikirim.
# Data untuk "Designing objects that tell stories" berhasil dikirim.
# Data untuk "The astonishing hidden world of the deep ocean" berhasil dikirim.
# Data untuk "What's wrong with what we eat" berhasil dikirim.
# Data untuk "How the news distorts our worldview" berhasil dikirim.
# Data untuk "A thought experiment on the intelligence of crows" berhasil dikirim.
# Data untuk "Juggling as art ... and science" berhasil dikirim.
# Data untuk "Can we domesticate germs?" berhasil dikirim.
# Data untuk "6 ways mushrooms can save the world" berhasil dikirim.
# Data untuk "The thinking behind 50x15" berhasil dikirim.
# Data untuk "Wake up! It's They Might Be Giants!" berhasil dikirim.
# Data untuk "CERN's supercollider" berhasil dikirim.
# Data untuk "Making sense of string theory" berhasil dikirim.
# Data untuk "Where does creativity hide?" berhasil dikirim.
# Data untuk "World-class health care" berhasil dikirim.
# Data untuk "The new open-source economics" berhasil dikirim.
# Data untuk "Inventing instruments that unlock new music" berhasil dikirim.
# Data untuk "Free or cheap Wii Remote hacks" berhasil dikirim.
# Data untuk "New thinking on the climate crisis" berhasil dikirim.
# Data untuk "Questioning the universe" berhasil dikirim.
# Data untuk "A new kind of music video" berhasil dikirim.
# Data untuk "Sputnik mania" berhasil dikirim.
# Data untuk "The search for the true face of Leonardo" berhasil dikirim.
# Data untuk ""M'Bifo"" berhasil dikirim.
# Data untuk "The call to learn" berhasil dikirim.
# Data untuk "A look inside the brain in real time" berhasil dikirim.
# Data untuk "My green agenda for architecture" berhasil dikirim.
# Data untuk "My wish: Find the next Einstein in Africa" berhasil dikirim.
# Data untuk "My wish: The Charter for Compassion" berhasil dikirim.
# Data untuk "My wish: Once Upon a School" berhasil dikirim.
# Data untuk "My days as a young rebel" berhasil dikirim.
# Data untuk "My stroke of insight" berhasil dikirim.
# Data untuk "5 predictions, from 1984" berhasil dikirim.
# Data untuk "On the verge of creating synthetic life" berhasil dikirim.
# Data untuk "A powerful idea about ideas" berhasil dikirim.
# Data untuk "A preview of the WorldWide Telescope" berhasil dikirim.
# Data untuk "Model rocketry" berhasil dikirim.
# Data untuk "A parable for Kenya" berhasil dikirim.
# Data untuk "Juggle and jest" berhasil dikirim.
# Data untuk "The Jill and Julia Show" berhasil dikirim.
# Data untuk "Building uniqueness" berhasil dikirim.
# Data untuk "The story of Project Orion" berhasil dikirim.
# Data untuk "The untouchable music of the theremin" berhasil dikirim.
# Data untuk "The new power of collaboration" berhasil dikirim.
# Data untuk "A plant's-eye view" berhasil dikirim.
# Data untuk "An illustrated journey through Rome" berhasil dikirim.
# Data untuk "A song of the city" berhasil dikirim.
# Data untuk "The idea behind Zipcar (and what comes next)" berhasil dikirim.
# Data untuk "TED's nonprofit transition" berhasil dikirim.
# Data untuk "An unusual glimpse at celebrity" berhasil dikirim.
# Data untuk "The music wars" berhasil dikirim.
# Data untuk "The life-long learner" berhasil dikirim.
# Data untuk "Rebuilding a neighborhood with beauty, dignity, hope" berhasil dikirim.
# Data untuk ""Tembererana"" berhasil dikirim.
# Data untuk "A master architect asks, Now what?" berhasil dikirim.
# Data untuk "Treat design as art" berhasil dikirim.
# Data untuk "Underwater astonishments" berhasil dikirim.
# Data untuk "The mystery box" berhasil dikirim.
# Data untuk "The emergent genius of ant colonies" berhasil dikirim.
# Data untuk "We're worried about local warming ... in your lap" berhasil dikirim.
# Data untuk "Tales of passion" berhasil dikirim.
# Data untuk "5 dangerous things you should let your kids do" berhasil dikirim.
# Data untuk "The lost art of letter-writing" berhasil dikirim.
# Data untuk "Why aren't we more compassionate?" berhasil dikirim.
# Data untuk "A performance of "Mathemagic"" berhasil dikirim.
# Data untuk "Winning the oil endgame" berhasil dikirim.
# Data untuk "Beauty, truth and ... physics?" berhasil dikirim.
# Data untuk "Design and destiny" berhasil dikirim.
# Data untuk "The fractals at the heart of African designs" berhasil dikirim.
# Data untuk "The sticky wonder of gecko feet" berhasil dikirim.
# Data untuk "The case for optimism" berhasil dikirim.
# Data untuk "Using biology to rethink the energy challenge" berhasil dikirim.
# Data untuk "A critical look at geoengineering against climate change" berhasil dikirim.
# Data untuk "Playing with DNA that self-assembles" berhasil dikirim.
# Data untuk "Laws that choke creativity" berhasil dikirim.
# Data untuk "The habits of happiness" berhasil dikirim.
# Data untuk "How electroshock therapy changed me" berhasil dikirim.
# Data untuk "A commodities exchange for Ethiopia" berhasil dikirim.
# Data untuk "3 clues to understanding your brain" berhasil dikirim.
# Data untuk "The anthropology of mobile phones" berhasil dikirim.
# Data untuk "The illustrated woman" berhasil dikirim.
# Data untuk "Building "self-aware" robots" berhasil dikirim.
# Data untuk "Life at 30,000 feet" berhasil dikirim.
# Data untuk "My magic moves" berhasil dikirim.
# Data untuk "This is Saturn" berhasil dikirim.
# Data untuk "A flight on solar wings" berhasil dikirim.
# Data untuk "10 ways the world could end" berhasil dikirim.
# Data untuk "Designing for simplicity" berhasil dikirim.
# Data untuk "The search for humanity's roots" berhasil dikirim.
# Data untuk "An Iraq war movie crowd-sourced from soldiers" berhasil dikirim.
# Data untuk "The surprising decline in violence" berhasil dikirim.
# Data untuk "What our language habits reveal" berhasil dikirim.
# Data untuk "My creations, a new form of life" berhasil dikirim.
# Data untuk "Aid for Africa? No thanks." berhasil dikirim.
# Data untuk "The joy of lexicography" berhasil dikirim.
# Data untuk "Luke, a new prosthetic arm for soldiers" berhasil dikirim.
# Data untuk "My journey into movies that matter" berhasil dikirim.
# Data untuk ""Woza"" berhasil dikirim.
# Data untuk ""Thula Mama"" berhasil dikirim.
# Data untuk "Patient capitalism" berhasil dikirim.
# Data untuk "Telling stories from Africa" berhasil dikirim.
# Data untuk "How to educate leaders? Liberal arts" berhasil dikirim.
# Data untuk "Why invest in Africa" berhasil dikirim.
# Data untuk "How I built a windmill" berhasil dikirim.
# Data untuk "Aid versus trade" berhasil dikirim.
# Data untuk "Africa's cheetahs versus hippos" berhasil dikirim.
# Data untuk "How to get (a new) hip" berhasil dikirim.
# Data untuk "Visualizing the wonder of a living cell" berhasil dikirim.
# Data untuk "The  4 a.m. mystery" berhasil dikirim.
# Data untuk "Spore, birth of a game" berhasil dikirim.
# Data untuk "Flip your thinking on AIDS in Africa" berhasil dikirim.
# Data untuk "The Web's secret stories" berhasil dikirim.
# Data untuk "The potential of regenerative medicine" berhasil dikirim.
# Data untuk "Dangerous memes" berhasil dikirim.
# Data untuk "Inside the world's deepest caves" berhasil dikirim.
# Data untuk "New insights on poverty" berhasil dikirim.
# Data untuk "Tour Microsoft's Virtual Earth" berhasil dikirim.
# Data untuk "A string quartet plays "Blue Room"" berhasil dikirim.
# Data untuk "Let's rethink America's military strategy" berhasil dikirim.
# Data untuk "A memorial at Ground Zero" berhasil dikirim.
# Data untuk "We can be Buddhas" berhasil dikirim.
# Data untuk "Rethink the desktop with BumpTop" berhasil dikirim.
# Data untuk "Want to help Africa? Do business here" berhasil dikirim.
# Data untuk "Salvation (and profit) in greentech" berhasil dikirim.
# Data untuk "How PhotoSynth can connect the world's images" berhasil dikirim.
# Data untuk "Swim with the giant sunfish" berhasil dikirim.
# Data untuk "How brain science will change computing" berhasil dikirim.
# Data untuk "What squatter cities can teach us" berhasil dikirim.
# Data untuk "Human-centered design" berhasil dikirim.
# Data untuk "The ghastly tragedy of the suburbs" berhasil dikirim.
# Data untuk ""Black Men Ski"" berhasil dikirim.
# Data untuk "The genesis of Google" berhasil dikirim.
# Data untuk "Cape Breton fiddling in reel time" berhasil dikirim.
# Data untuk "Technology's long tail" berhasil dikirim.
# Data untuk ""La Vie en Rose"" berhasil dikirim.
# Data untuk "A comic sendup of TED2006" berhasil dikirim.
# Data untuk "Militant atheism" berhasil dikirim.
# Data untuk "Why would God create a tsunami?" berhasil dikirim.
# Data untuk ""What You've Got"" berhasil dikirim.
# Data untuk ""Kiteflyer's Hill"" berhasil dikirim.
# Data untuk "A mockingbird remix of TED2006" berhasil dikirim.
# Data untuk "The electricity metaphor for the web's future" berhasil dikirim.
# Data untuk "Cradle to cradle design" berhasil dikirim.
# Data untuk "How to truly listen" berhasil dikirim.
# Data untuk "The illusion of consciousness" berhasil dikirim.
# Data untuk "Casting a spell on the cello" berhasil dikirim.
# Data untuk "Global warming's theme song, "Manhattan in January"" berhasil dikirim.
# Data untuk "Sampling the ocean's DNA" berhasil dikirim.
# Data untuk "Singing "What I Want"" berhasil dikirim.
# Data untuk "The route to a sustainable future" berhasil dikirim.
# Data untuk "Art with wire, sugar, chocolate and string" berhasil dikirim.
# Data untuk "What separates us from chimpanzees?" berhasil dikirim.
# Data untuk "How to get your ideas to spread" berhasil dikirim.
# Data untuk "The story of life in photographs" berhasil dikirim.
# Data untuk "How architecture can connect us" berhasil dikirim.
# Data untuk "Happiness by design" berhasil dikirim.
# Data untuk "The gentle genius of bonobos" berhasil dikirim.
# Data untuk "The life code that will reshape the future" berhasil dikirim.
# Data untuk "Software (as) art" berhasil dikirim.
# Data untuk "Great cars are great art" berhasil dikirim.
# Data untuk "The shrimp with a kick!" berhasil dikirim.
# Data untuk "How we discovered DNA" berhasil dikirim.
# Data untuk "A philosophical quest for our biggest problems" berhasil dikirim.
# Data untuk "To invent is to give" berhasil dikirim.
# Data untuk "Design is in the details" berhasil dikirim.
# Data untuk "Biomimicry's surprising lessons from nature's engineers" berhasil dikirim.
# Data untuk "Visual illusions that show how we (mis)think" berhasil dikirim.
# Data untuk "My wish: Let my photographs bear witness" berhasil dikirim.
# Data untuk "My wish: Rebuilding Rwanda" berhasil dikirim.
# Data untuk "My wish: Build the Encyclopedia of Life" berhasil dikirim.
# Data untuk "In praise of slowness" berhasil dikirim.
# Data untuk "Unleash your creativity in a Fab Lab" berhasil dikirim.
# Data untuk "Everyday inventions" berhasil dikirim.
# Data untuk "A dance of "Symbiosis"" berhasil dikirim.
# Data untuk "Four American characters" berhasil dikirim.
# Data untuk "How the "ghost map" helped end a killer disease" berhasil dikirim.
# Data untuk "The era of open innovation" berhasil dikirim.
# Data untuk "Progress is not a zero-sum game" berhasil dikirim.
# Data untuk "Is this our final century?" berhasil dikirim.
# Data untuk "Photos of endangered cultures" berhasil dikirim.
# Data untuk "Dreams from endangered cultures" berhasil dikirim.
# Data untuk "Global priorities bigger than climate change" berhasil dikirim.
# Data untuk "The hidden world of shadow cities" berhasil dikirim.
# Data untuk "If I controlled the Internet" berhasil dikirim.
# Data untuk "8 secrets of success" berhasil dikirim.
# Data untuk "The killer American diet that's sweeping the planet" berhasil dikirim.
# Data untuk "Fight injustice with raw video" berhasil dikirim.
# Data untuk "The accelerating power of technology" berhasil dikirim.
# Data untuk "How technology evolves" berhasil dikirim.
# Data untuk "Why people believe weird things" berhasil dikirim.
# Data untuk "How juries are fooled by statistics" berhasil dikirim.
# Data untuk "My wish: Three actions for Africa" berhasil dikirim.
# Data untuk "My wish: Three unusual medical inventions" berhasil dikirim.
# Data untuk "My wish: Manufactured landscapes and green education" berhasil dikirim.
# Data untuk "Why did I ski to the North Pole?" berhasil dikirim.
# Data untuk "The real future of space exploration" berhasil dikirim.
# Data untuk "Why we should invest in a free press" berhasil dikirim.
# Data untuk "How to rebuild a broken state" berhasil dikirim.
# Data untuk "How mobile phones can fight poverty" berhasil dikirim.
# Data untuk "Invest in Africa's own solutions" berhasil dikirim.
# Data untuk "Meet the future of cancer research" berhasil dikirim.
# Data untuk "A roadmap to end aging" berhasil dikirim.
# Data untuk "The surprising science of happiness" berhasil dikirim.
# Data untuk "The paradox of choice" berhasil dikirim.
# Data untuk "Choice, happiness and spaghetti sauce" berhasil dikirim.
# Data untuk "The freakonomics of crack dealing" berhasil dikirim.
# Data untuk "Chemical scum that dream of distant quasars" berhasil dikirim.
# Data untuk "Why the universe seems so strange" berhasil dikirim.
# Data untuk "Why we love, why we cheat" berhasil dikirim.
# Data untuk "Happiness in body and soul" berhasil dikirim.
# Data untuk "Meet the founder of the blog revolution" berhasil dikirim.
# Data untuk "Nerdcore comedy" berhasil dikirim.
# Data untuk "The birth of the open-source learning revolution" berhasil dikirim.
# Data untuk "The birth of Wikipedia" berhasil dikirim.
# Data untuk "Organic design, inspired by nature" berhasil dikirim.
# Data untuk "Simple designs to save a life" berhasil dikirim.
# Data untuk "Improvising on piano, aged 14" berhasil dikirim.
# Data untuk "An 11-year-old's magical violin" berhasil dikirim.
# Data untuk "The radical promise of the multi-touch interface" berhasil dikirim.
# Data untuk "One Laptop per Child" berhasil dikirim.
# Data untuk "My wish: A call for open-source architecture" berhasil dikirim.
# Data untuk "My wish: A global day of film" berhasil dikirim.
# Data untuk "My wish: Help me stop pandemics" berhasil dikirim.
# Data untuk "Let's teach religion — all religion — in schools" berhasil dikirim.
# Data untuk "A life of purpose" berhasil dikirim.
# Data untuk "Letting go of God" berhasil dikirim.
# Data untuk "Behind the design of Seattle's library" berhasil dikirim.
# Data untuk "The best stats you've ever seen" berhasil dikirim.
# Data untuk "Do schools kill creativity?" berhasil dikirim.
# Data untuk "Greening the ghetto" berhasil dikirim.
# Data untuk "Simplicity sells" berhasil dikirim.
# Data untuk "Averting the climate crisis" berhasil dikirim.
